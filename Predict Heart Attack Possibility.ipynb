# %%
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from scipy.stats import binom
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
import statsmodels.api as sm
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
df= pd.read_csv(r"C:\Users\Sahand\Desktop\STAT Project\heart.csv")
print(df.head(20))
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# # Random Sample

# %%
subset = df.sample(n=3)

# %%
subset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 254   59    1   3       160   273    0        0      125      0      0.0
# 57    45    1   0       115   260    0        0      185      0      0.0
# 62    52    1   3       118   186    0        0      190      0      0.0
#
#      slope  ca  thal  target
# 254      2   0     2       0
# 57       2   0     2       1
# 62       1   0     1       1

# %% [markdown]
# # non-random sample

# %%
condition = df['thalach'] < 161

# %%
true_index = condition[condition == True].index

# %%
subset = df[condition].sample(n = 10)
subset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 129   74    0   1       120   269    0        0      121      1      0.2
# 253   67    1   0       100   299    0        0      125      1      0.9
# 169   53    1   0       140   203    1        0      155      1      3.1
# 96    62    0   0       140   394    0        0      157      0      1.2
# 225   70    1   0       145   174    0        1      125      1      2.6
# 38    65    0   2       155   269    0        1      148      0      0.8
# 110   64    0   0       180   325    0        1      154      1      0.0
# 210   57    1   2       128   229    0        0      150      0      0.4
# 138   57    1   0       110   201    0        1      126      1      1.5
# 39    65    0   2       160   360    0        0      151      0      0.8
#
#      slope  ca  thal  target
# 129      2   1     2       1
# 253      1   2     2       0
# 169      0   0     3       0
# 96       1   0     2       1
# ...

# %% [markdown]
# # sampling with replacement

# %%
df.sample(n=5, replace=True)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 70    54    1   2       120   258    0        0      147      0      0.4
# 132   42    1   1       120   295    0        1      162      0      0.0
# 300   68    1   0       144   193    1        1      141      0      3.4
# 22    42    1   0       140   226    0        1      178      0      0.0
# 72    29    1   1       130   204    0        0      202      0      0.0
#
#      slope  ca  thal  target
# 70       1   0     3       1
# 132      2   0     2       1
# 300      1   2     3       0
# 22       2   0     2       1
# 72       2   0     2       1

# %% [markdown]
# # sampling without replacement

# %%
df.sample(n=5, replace=False)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 74   43    0   2       122   213    0        1      165      0      0.2
# 6    56    0   1       140   294    0        0      153      0      1.3
# 97   52    1   0       108   233    1        1      147      0      0.1
# 33   54    1   2       125   273    0        0      152      0      0.5
# 12   49    1   1       130   266    0        1      171      0      0.6
#
#     slope  ca  thal  target
# 74      1   0     2       1
# 6       1   0     2       1
# 97      2   3     3       1
# 33      0   1     2       1
# 12      2   0     2       1

# %% [markdown]
# # Representive Sample

# %%
subset = df.sample(n=20)
subset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 20    59    1   0       135   234    0        1      161      0      0.5
# 68    44    1   1       120   220    0        1      170      0      0.0
# 144   76    0   2       140   197    0        2      116      0      1.1
# 194   60    1   2       140   185    0        0      155      0      3.0
# 95    53    1   0       142   226    0        0      111      1      0.0
# 83    52    1   3       152   298    1        1      178      0      1.2
# 187   54    1   0       124   266    0        0      109      1      2.2
# 161   55    0   1       132   342    0        1      166      0      1.2
# 56    48    1   0       122   222    0        0      186      0      0.0
# 21    44    1   2       130   233    0        1      179      1      0.4
# 57    45    1   0       115   260    0        0      185      0      0.0
# 58    34    1   3       118   182    0        0      174      0      0.0
# ...

# %% [markdown]
# # systematic random sampling technique

# %%
import numpy as np
import pandas as pd

n= 303
 
# Define systematic sampling function
def systematic_sampling(df, step):
 
    indexes = np.arange(0, len(df), step=step)
    systematic_sample = df.iloc[indexes]
    return systematic_sample
 
 
# Obtain a systematic sample and save it in a new variable
systematic_sample = systematic_sampling(df, 5)
 
# View sampled data frame
display(systematic_sample)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 5     57    1   0       140   192    0        1      148      0      0.4
# 10    54    1   0       140   239    0        1      160      0      1.2
# 15    50    0   2       120   219    0        1      158      0      1.6
# 20    59    1   0       135   234    0        1      161      0      0.5
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 280   42    1   0       136   315    0        1      125      1      1.8
# 285   46    1   0       140   311    0        1      120      1      1.8
# 290   61    1   0       148   203    0        1      161      0      0.0
# 295   63    1   0       140   187    0        0      144      1      4.0
# 300   68    1   0       144   193    1        1      141      0      3.4
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 5        1   0     1       1
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.replace(to_replace= r'^\s*$', value=np.nan,regex=True, inplace=True ) #replace any unit value that only contains " ", space
df.isnull().any() #check whether each column contains a missing value
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %% [markdown]
# # Logistic Regression

# %%
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
estimators=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
       'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']

# %% [markdown]
# ## Identifying features and target

# %%
y=df['target'] ### defining the target value (dependent variable)
x1=df[estimators] ### defining the features (independent variable)

# %% [markdown]
# ## Creating Regression Model

# %%
x=sm.add_constant(x1) ### adding constant
reg_log =sm.Logit(y,x) 
result_log = reg_log.fit() ### fitting the regression
# Out:
# Optimization terminated successfully.
#          Current function value: 0.348904
#          Iterations 7
# C:\Users\Sahand\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
result_log.summary() ### maximum likelihood estimation (MLE) Table
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 target   No. Observations:                  303
# Model:                          Logit   Df Residuals:                      289
# Method:                           MLE   Df Model:                           13
# Date:                Sun, 12 Dec 2021   Pseudo R-squ.:                  0.4937
# Time:                        13:06:58   Log-Likelihood:                -105.72
# converged:                       True   LL-Null:                       -208.82
# Covariance Type:            nonrobust   LLR p-value:                 7.262e-37
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4505      2.571      1.342      0.180      -1.590       8.490
# age           -0.0049      0.023     -0.212      0.832      -0.050       0.041
# ...

# %% [markdown]
# As we can see that p-value of AGE and FBS are high and hence they insignificant in our regression model, so we deroped them.

# %%
df_new=df.drop(['age','fbs'],axis=1)
df_new
# Out:
#      sex  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  ca  \
# 0      1   3       145   233        0      150      0      2.3      0   0
# 1      1   2       130   250        1      187      0      3.5      0   0
# 2      0   1       130   204        0      172      0      1.4      2   0
# 3      1   1       120   236        1      178      0      0.8      2   0
# 4      0   0       120   354        1      163      1      0.6      2   0
# ..   ...  ..       ...   ...      ...      ...    ...      ...    ...  ..
# 298    0   0       140   241        1      123      1      0.2      1   0
# 299    1   3       110   264        1      132      0      1.2      1   0
# 300    1   0       144   193        1      141      0      3.4      1   2
# 301    1   0       130   131        1      115      1      1.2      1   1
# 302    0   1       130   236        0      174      0      0.0      1   1
#
#      thal  target
# 0       1       1
# 1       2       1
# 2       2       1
# ...

# %%
df_new.columns.values
# Out:
# array(['sex', 'cp', 'trestbps', 'chol', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal', 'target'], dtype=object)

# %%
df_new.columns.values
# Out:
# array(['sex', 'cp', 'trestbps', 'chol', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal', 'target'], dtype=object)

# %%
estimators_new=['sex', 'cp', 'trestbps', 'chol', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal']

# %% [markdown]
# ## Runnig Regression having new array and after dropping significant variables

# %%
y_=df_new['target']
x1_= df_new[estimators_new]
x_=sm.add_constant(x1_)
reg_log_ =sm.Logit(y_,x_)
result_log_ = reg_log_.fit()
result_log_.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.348982
#          Iterations 7
# C:\Users\Sahand\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 target   No. Observations:                  303
# Model:                          Logit   Df Residuals:                      291
# Method:                           MLE   Df Model:                           11
# Date:                Sun, 12 Dec 2021   Pseudo R-squ.:                  0.4936
# Time:                        14:37:24   Log-Likelihood:                -105.74
# converged:                       True   LL-Null:                       -208.82
# ...

# %% [markdown]
# # In this part Logistic regression is runned again

# %% [markdown]
# # 2. Regressionc and Evaluation

# %%
from sklearn.linear_model import LogisticRegression

X = df_new.iloc[:, :-1].values
y = df_new.iloc[:, -1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)
lr_classifier = LogisticRegression()
lr_classifier.fit(X_train, y_train)

y_pred_lr = lr_classifier.predict(X_test)

# Lets measure the accuracy of the model using the confusion matrix.
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_lr)

corr_pred = cm[0, 0] + cm[1, 1]
total = cm.sum()
corr_pred_per = round(corr_pred/total*100, 2)
print('Percentage of correct predictions: ', corr_pred_per)
# Out:
# Percentage of correct predictions:  87.1
# C:\Users\Sahand\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Chapter 4. Probability

# %%
df.value_counts()
# Out:
# age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 38   1    2   138       175   0    1        173      0      0.0      2      4   2     1         2
# 59   1    0   110       239   0    0        142      1      1.2      1      1   3     0         1
#           2   126       218   1    1        134      0      2.2      1      1   1     0         1
#           1   140       221   0    1        164      1      0.0      2      0   2     1         1
#           0   170       326   0    0        140      1      3.4      0      0   3     0         1
#                                                                                                ..
# 51   1    2   94        227   0    1        154      1      0.0      2      1   3     1         1
#           0   140       299   0    1        173      1      1.6      2      0   3     0         1
#                         298   0    1        122      1      4.2      1      3   3     0         1
# ...

# %%
df['fbs'].value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
import statistics

# %%
statistics.mode(df['age'])
# Out:
# 58

# %%
statistics.mode(df['sex'])
# Out:
# 1

# %%
statistics.mode(df['cp'])
# Out:
# 0

# %%
statistics.mode(df['trestbps'])
# Out:
# 120

# %%
statistics.mode(df['chol'])
# Out:
# 204

# %%
statistics.mode(df['fbs'])
# Out:
# 0

# %%
statistics.mode(df['restecg'])
# Out:
# 1

# %%
statistics.mode(df['thalach'])
# Out:
# 162

# %%
statistics.mode(df['exang'])
# Out:
# 0

# %%
statistics.mode(df['oldpeak'])
# Out:
# 0.0

# %%
statistics.mode(df['slope'])
# Out:
# 2

# %%
statistics.mode(df['ca'])
# Out:
# 0

# %%
statistics.mode(df['thal'])
# Out:
# 2

# %%
statistics.mode(df['target'])
# Out:
# 1
